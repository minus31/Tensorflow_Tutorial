# %%
# tensor flow는 gpu버전으로 다운 받읍시다. 
# !nvidia-smi

# 터미널 상에서 
watch nvidia-smi
nvidia-smi -lms # 실시간 움직이는 것을 볼 수 있다. 
cuda_visible_devices=0 phthon3 model
# Out:
# Fri Dec  8 07:49:59 2017
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 375.66                 Driver Version: 375.66                    |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |===============================+======================+======================|
# |   0  Tesla K80           Off  | 0000:00:17.0     Off |                    0 |
# | N/A   43C    P8    31W / 149W |      0MiB / 11439MiB |      0%      Default |
# +-------------------------------+----------------------+----------------------+
# |   1  Tesla K80           Off  | 0000:00:18.0     Off |                    0 |
# | N/A   41C    P0    69W / 149W |      0MiB / 11439MiB |      0%      Default |
# ...

# %%
# gpu선택하여 실행하기 
# !export CUDA_VISIBLE=2

# %%
# !nvidia-smi #-lms
# Out:
# Fri Dec  8 07:58:31 2017
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 375.66                 Driver Version: 375.66                    |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |===============================+======================+======================|
# |   0  Tesla K80           Off  | 0000:00:17.0     Off |                    0 |
# | N/A   39C    P8    27W / 149W |      0MiB / 11439MiB |      0%      Default |
# +-------------------------------+----------------------+----------------------+
# |   1  Tesla K80           Off  | 0000:00:18.0     Off |                    0 |
# | N/A   37C    P8    29W / 149W |      0MiB / 11439MiB |      0%      Default |
# ...
